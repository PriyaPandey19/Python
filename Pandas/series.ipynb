# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #series

# %%
labels =['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10, 2:20, 3:30}

pd.Series(my_list)

pd.Series(my_list, index=labels)

pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
